# %% [markdown]
# ## while == for+if
# Let’s say we would like to iterate through list <code>dates</code> and stop at the year 1973, then print out the number of iterations. This can be done with the following block of code:

# %%
# My Code
# While Loop Example
dates = [1982, 1980, 1973, 2000]

i = 0
year = dates[0]

while(year != 1973):    
    print(year)
    i = i + 1
    year = dates[i]
    
print("It took ", i ,"repetitions to get out of the loop.")

# My Code
# For Loop while conversion
i = 0
for d in dates:
    if d == 1973:
        break 
    print(d)
    i += 1

print("It took ", i, "repetitions to get out of the loop.")
# Out:
# 1982
# 1980
# It took  2 repetitions to get out of the loop.
# 1982
# 1980
# It took  2 repetitions to get out of the loop.

# %% [markdown]
# ## More examples
# Write a while loop to display the values of the Rating of an album playlist stored in the list PlayListRatings. If the score is less than 6, exit the loop. The list PlayListRatings is given by: PlayListRatings = [10, 9.5, 10, 8, 7.5, 5, 10, 10]

# %%
PlayListRatings = [10, 9.5, 10, 8, 7.5, 5, 10, 10]

# My Code
for n in PlayListRatings:
    if n <= 6:
        break
    print(n)
print("")

# My Code
i = 0
while(PlayListRatings[i] >= 6):
    print(PlayListRatings[i])
    i += 1
print("")

# My Code
i = 0
rating = PlayListRatings[0]
while(rating >= 6):    
    print(rating)
    i = i + 1
    rating = PlayListRatings[i]
print("")

#solution:
i = 0
rating = PlayListRatings[0]
while(i < len(PlayListRatings) and rating >= 6):
    print(rating)
    i = i + 1 
    rating = PlayListRatings[i]
# Out:
# 10
# 9.5
# 10
# 8
# 7.5
#
# 10
# 9.5
# 10
# 8
# 7.5
#
# 10
# 9.5
# 10
# 8
# 7.5
#
# 10
# 9.5
# 10
# 8
# 7.5

# %% [markdown]
# Write a while loop to copy the strings <code>'orange'</code> of the list <code>squares</code> to the list <code>new_squares</code>. Stop and exit the loop if the value on the list is not <code>'orange'</code>:

# %%
# My Code
squares = ['orange', 'orange', 'purple', 'blue ', 'orange']
new_squares = []

for s in squares:
    if s == 'orange':
        new_squares.append(s)
    else:
        print(new_squares)
        break

# My Code
squares = ['orange', 'orange', 'purple', 'blue ', 'orange']
new_squares = []
i=0

while(squares[i] == 'orange'):
    new_squares.append(squares[i])
    i += 1
print(new_squares)

# My Code
squares = ['orange', 'orange', 'purple', 'blue ', 'orange']
new_squares = []
i = 0

while(set(new_squares) == {'orange'} or new_squares == []):
    new_squares.append(squares[i])
    i += 1
print(new_squares[:-1])

#solution:
squares = ['orange', 'orange', 'purple', 'blue ', 'orange']
new_squares = []
i = 0

while(i < len(squares) and squares[i] == 'orange'):
    new_squares.append(squares[i])
    i = i + 1
print (new_squares)
# Out:
# ['orange', 'orange']
# ['orange', 'orange']
# ['orange', 'orange']
# ['orange', 'orange']

# %% [markdown]
# ### Some real-life problems!
# Your little brother has just learned multiplication tables in school. Today he has learned tables of 6 and 7. Help him memorise both the tables by printing them using <code>for</code> loop.

# %%
# My Code
for n in range(0,11):
    print(f"Table of 6 x {n} = {6*n}")
    print(f"Table of 7 x {n} = {7*n}")
    

#solution:
print("Multiplication table of 6:")
for i in range (10):
    print("6*",i,"=",6*i)
print("Multiplication table of 7:")
for i in range (10):
    print("7*",i,"=",7*i)
# Out:
# Table of 6 x 0 = 0
# Table of 7 x 0 = 0
# Table of 6 x 1 = 6
# Table of 7 x 1 = 7
# Table of 6 x 2 = 12
# Table of 7 x 2 = 14
# Table of 6 x 3 = 18
# Table of 7 x 3 = 21
# Table of 6 x 4 = 24
# Table of 7 x 4 = 28
# Table of 6 x 5 = 30
# Table of 7 x 5 = 35
# Table of 6 x 6 = 36
# Table of 7 x 6 = 42
# Table of 6 x 7 = 42
# Table of 7 x 7 = 49
# Table of 6 x 8 = 48
# Table of 7 x 8 = 56
# Table of 6 x 9 = 54
# Table of 7 x 9 = 63
# Table of 6 x 10 = 60
# Table of 7 x 10 = 70
# Multiplication table of 6:
# 6* 0 = 0
# 6* 1 = 6
# 6* 2 = 12
# 6* 3 = 18
# 6* 4 = 24
# 6* 5 = 30
# 6* 6 = 36
# 6* 7 = 42
# 6* 8 = 48
# 6* 9 = 54
# Multiplication table of 7:
# 7* 0 = 0
# 7* 1 = 7
# 7* 2 = 14
# 7* 3 = 21
# 7* 4 = 28
# 7* 5 = 35
# 7* 6 = 42
# 7* 7 = 49
# 7* 8 = 56
# 7* 9 = 63

# %% [markdown]
# ## Come up with a function that divides the first input by the second input:
#
# ### Using `if/else` or `try-ecept` Best Practice Recommendation:
#
# While both methods are valid and have their uses, the `try-except` approach is often more aligned with Pythonic principles of "it's easier to ask for forgiveness than permission" (EAFP). This principle suggests that you should assume the best and deal with problems if they actually occur.
# In this case, the `try-except` version is preferable because it cleanly handles the types of errors that division might produce, such as `ZeroDivisionError` and `TypeError`, without needing multiple conditional checks beforehand. It's efficient, clean, and adheres to common Python practices.
#
#
#
# ### Using the`try-ecept` `else` Block:
#
# *   **Clarity and Separation**: The `else` block in a `try-except` structure runs only if the code inside the `try` block did not raise an exception. This clearly separates the code that might cause exceptions from the code that should run only if no exceptions were raised. It's useful for keeping the error handling cleanly separated from normal execution.
# *   **Safety**: It prevents accidentally catching exceptions that weren't meant to be caught by the `try` block, which might happen if you put too much code in the `try` block.
#
# ### Best Practice:
#
# *   **Use `else` when**: You have additional code that should only execute if the `try` block did not raise an exception, and this code itself should not be covered by the preceding `except` clauses.
# *   **Use `return` in `try` when**: The function needs to output a result directly from the attempted operation, and you want to handle the success case as soon as the operation completes successfully.
#
# In practice, the choice between using an `else` block or a `return` statement inside the `try` block often comes down to the specific requirements of your application and which option makes the code more readable and maintainable.

# %%
# My Code
def divAbyB(a,b):
    if b != 0 and isinstance(a, (int, float)) and isinstance(b, (int, float)):
        c = a/b
        print(c)
        return c
    
    elif b == 0:
        print("Error: Cannot divide by zero")
        return(None)
    
    else:
        print("Error: There are non-numeric values")
        return(None)
        
divAbyB(4,"a")


# using try and except
def divAbyB(a,b):
    try:
        c = a/b
        print(c)
        return c
    
    except ZeroDivisionError:
        print("Error: Cannot divide by zero")
        return(None)
    
    except TypeError:
        print("Error: There are non-numeric values")
        return(None)

divAbyB(4,"a")


#solution:
def div(a, b):
    return(a/b)
# Out:
# Error: There are non-numeric values
# Error: There are non-numeric values

# %% [markdown]
# Write a function code to find total count of word little in the given string: "Mary had a little lamb Little lamb, little lamb Mary had a little lamb.Its fleece was white as snow And everywhere that Mary went Mary went, Mary went Everywhere that Mary went The lamb was sure to go"**

# %%
# My Code
def countWords(string, word):
    counting= string.lower().split().count(word.lower())
    print("There are",counting, word,"words in the text independent of the case size.")
    return(counting)
    
countWords("Mary had a little lamb Little lamb, little lamb Mary had a little lamb.Its fleece was white as snow And everywhere that Mary went Mary went, Mary went Everywhere that Mary went The lamb was sure to go", "LITTLE")


#solution:
# Python Program to Count words in a String using Dictionary
def freq(string,passedkey):

    #step1: A list variable is declared and initialized to an empty list.
    words = []

    #step2: Break the string into list of words
    words = string.split() # or string.lower().split()

    #step3: Declare a dictionary
    Dict = {}

    #step4: Use for loop to iterate words and values to the dictionary
    for key in words:
        if(key == passedkey):
            Dict[key] = words.count(key)   
    #step5: Print the dictionary
    print("Total Count:",Dict)

#step6: Call function and pass string in it
freq("Mary had a little lamb Little lamb, little lamb Mary had a little lamb.Its fleece was white as snow And everywhere that Mary went Mary went, Mary went \
Everywhere that Mary went The lamb was sure to go","little")
# Out:
# There are 4 LITTLE words in the text independent of the case size.
# Total Count: {'little': 3}

# %% [markdown]
# ## Creating a Class
# Now we are going to create a class Circle, but first, we are going to import a library to draw the objects:
# ```
# # Import the library
# import importlib.util
# if importlib.util.find_spec("matplotlib") is None:
#     !pip install matplotlib
#
# import matplotlib.pyplot as plt
# %matplotlib inline
#
# # Create a class Circle
#
# class Circle(object):
#
#     # Constructor
#     def __init__(self, radius=3, color='blue'):
#         self.radius = radius
#         self.color = color
#
#     # Method
#     def add_radius(self, r):
#         self.radius = self.radius + r
#         return(self.radius)
#
#     # Method
#     def drawCircle(self):
#         plt.gca().add_patch(plt.Circle((0, 0), radius=self.radius, fc=self.color))
#         plt.axis('scaled')
#         plt.show()
#
# RedCircle.add_radius(2)
#
# RedCircle = Circle(10, 'red')
# print(dir(RedCircle))
# print(RedCircle.radius)
# print(RedCircle.color)
# RedCircle.drawCircle()
# ```
# ![alt text](8c07d95f-3a0e-4e87-a898-ae8e43d7c235.png)

# %% [markdown]
# Self exercice of playing with the class code so it can draw multiple circles instead of one of a time, giving the distance between each circle of its radius sum:

# %%
# My Code
# Import the library
import importlib.util
if importlib.util.find_spec("matplotlib") is None:
    # %pip install matplotlib
    
import matplotlib.pyplot as plt
# %matplotlib inline

# Create a class Circle
class Circle(object):
    
    # Constructor
    def __init__(self, radius=3, color='blue', center=(0, 0)):
        self.radius = radius
        self.color = color
        self.center = center
    
    # Method
    def add_radius(self, r):
        self.radius = self.radius + r
        return self.radius
    
    # Method
    def drawCircle(self):
        plt.gca().add_patch(plt.Circle(self.center, radius=self.radius, fc=self.color))
        plt.axis('scaled')


# Create a list of circles
circles = []

# Create N circles and add them to the list
N = 3  # Number of circles
spacing = 0  # Initial spacing
for i in range(N):
    radius = 1 + i  # Increase radius for each circle
    color = 'blue' if i % 2 == 0 else 'red'  # Alternate colors
    center = (radius + spacing, 0)  # Adjust x-coordinate for each circle
    circles.append(Circle(radius, color, center))
    spacing += 2 * radius  # Update spacing for next circle

# Draw circles side by side
for circle in circles:
    circle.drawCircle()

plt.show()

# %% [markdown]
# ## Scenario: Car dealership's inventory management system
# You are working on a Python program to simulate a car dealership's inventory management system. The system aims to model cars and their attributes accurately.
#
# Task-1. You are tasked with creating a Python program to represent vehicles using a class. Each car should have attributes for maximum speed and mileage.
#
# Task-2. Update the class with the default color for all vehicles," white".
#
# Task-3. Additionally, you need to create methods in the Vehicle class to assign seating capacity to a vehicle.
#
# Task-4. Create a method to display all the properties of an object of the class.
#
# Task-5. Additionally, you need to create two objects of the Vehicle class object that should have a max speed of 200kmph and mileage of 20kmpl with five seating capacities, and another car object should have a max speed of 180kmph and mileage of 25kmpl with four seating capacities.

# %%
# My Code
class CarInventory(object):
    
    def __init__(self, max_speed, mileage, color="white"):
        self.max_speed = max_speed
        self.mileage = mileage
        self.color = color
        self.seats = None
    
    def seating_cap (self, seats):
        self.seats = seats
        
    def show_all(self):
        print("Maximum Speed: ", self.max_speed)
        print("Mileage: ", self.mileage)
        print("Color: ", self.color)
        print("Seats: ", self.seats)
                
car1 = CarInventory("200kmph","20kmpl")
car1.seating_cap(5)
car1.show_all()

car2 = CarInventory("180kmph","25kmpl")
car2.seating_cap(4)
car2.show_all()

print("")

#solution:
class Vehicle:
    color = "white"

    def __init__(self, max_speed, mileage):
        self.max_speed = max_speed
        self.mileage = mileage
        self.seating_capacity = None

    def assign_seating_capacity(self, seating_capacity):
        self.seating_capacity = seating_capacity

    def display_properties(self):
        print("Properties of the Vehicle:")
        print("Color:", self.color)
        print("Maximum Speed:", self.max_speed)
        print("Mileage:", self.mileage)
        print("Seating Capacity:", self.seating_capacity)

# Creating objects of the Vehicle class
vehicle1 = Vehicle(200, 20)
vehicle1.assign_seating_capacity(5)
vehicle1.display_properties()

vehicle2 = Vehicle(180, 25)
vehicle2.assign_seating_capacity(4)
vehicle2.display_properties()
# Out:
# Maximum Speed:  200kmph
# Mileage:  20kmpl
# Color:  white
# Seats:  5
# Maximum Speed:  180kmph
# Mileage:  25kmpl
# Color:  white
# Seats:  4
#
# Properties of the Vehicle:
# Color: white
# Maximum Speed: 200
# Mileage: 20
# Seating Capacity: 5
# Properties of the Vehicle:
# Color: white
# Maximum Speed: 180
# Mileage: 25
# Seating Capacity: 4

# %% [markdown]
# ## Step 1: Define a string
# "Lorem ipsum dolor! diam amet, consetetur Lorem magna. sed diam nonumy eirmod tempor. diam et labore? et diam magna. et diam amet." <br>
# `givenstring="Lorem ipsum dolor! diam amet, consetetur Lorem magna. sed diam nonumy eirmod tempor. diam et labore? et diam magna. et diam amet."`
#
# ## Step 2: Define the class and its attributes
# 1. Create a class named TextAnalyzer.
# 2. Define the constructor `__init__` method that takes a text argument.
#
# ## Step 3: Implement a code to format the text in lowercase
# 1. Inside the constructor, convert the text argument to lowercase using the `lower()` method.
# 2. Then, remove punctuation marks (periods, exclamation marks, commas, and question marks) from the text using the `replace()` method.
# 3. Finally, assign the formatted text to a new attribute called fmtText.
#
# ## Step 4: Implement a code to count the frequency of all unique words
# * In this step, you will implement the `freqAll()` method with the below parameters:
#      1. Split the fmtText attribute into individual words using the `split()` method.
#      2. Create an empty dictionary to store the word frequency.
#      3. Iterate over the list of words and update the frequency dictionary accordingly.
#      4. Use `count` method for counting the occurence.
#      5. Return the frequency dictionary.
#
# ## Step 5: Implement a code to count the frequency of a specific word
# In step-5, you have to implement the `freqOf(word)` method that takes a word argument:
#    1. Create a method and pass the word that needs to be found.
#    2. Get the `freqAll` method to look for count and check if that word is in the list.
#    3. Return the count. If the word is not found, the count returned is 0.
#
# **Here you will be updating the above `TextAnalyzer` class with the points mentioned above.**
# ```
# #Press Shift+Enter to run the code
# class TextAnalyzer(object):
#
#     def __init__ (self, text):
#         # remove punctuation
#
#         # make text lowercase
#
#     def freqAll(self):
#         # split text into words
#
#         # Create dictionary
#
#     def freqOf(self,word):
#         # get frequency map
# ```

# %%
givenstring="Lorem ipsum dolor! diam amet, consetetur Lorem magna. sed diam nonumy eirmod tempor. diam et labore? et diam magna. et diam amet."

# My Code
class TextAnalzer(object):
    
    def __init__ (self, text):
        # remove punctuation
        self.text = text.replace('.', ' ').replace('!', ' ').replace(',', ' ').replace('?', ' ')
        
        # make text lowercase
        self.text = self.text.lower()
        
    def freqAll(self):        
        # split text into words
        self.split = self.text.split()
        
        # Create dictionary
        self.countWords = {}
        for word in set(self.split):
            self.countWords.update({word: self.split.count(word)})
            
        return(self.countWords)
    
    def freqOf(self,word):
            # Call freqAll() if countWords is None
        if self.countWords is None:
            self.freqAll()
            
        #if word.lower() in self.countWords:
        #    return(self.countWords[word.lower()])
        #else:
        #    return(0)
        return self.countWords.get(word.lower(), 0)
                
### solution:  
class TextAnalyzer(object):
    
    def __init__ (self, text):
        # remove punctuation
        formattedText = text.replace('.','').replace('!','').replace('?','').replace(',','')
        
        # make text lowercase
        formattedText = formattedText.lower()
        
        self.fmtText = formattedText
        
    def freqAll(self):        
        # split text into words
        wordList = self.fmtText.split(' ')
        
        # Create dictionary
        freqMap = {}
        for word in set(wordList): # use set to remove duplicates in list
            freqMap[word] = wordList.count(word)
        
        return freqMap
    
    def freqOf(self,word):
        # get frequency map
        freqDict = self.freqAll()
        
        if word in freqDict:
            return freqDict[word]
        else:
            return 0

# %%
new_text = TextAnalzer(givenstring)
counted_words = new_text.freqAll()

new_text.freqOf("diam")
# Out:
# 5

# %% [markdown]
# # Exercises
#
# ### Exercise 1
# Extract the required GDP data from the given URL using Web Scraping.
# You can use Pandas library to extract the required table directly as a DataFrame. Note that the required table is the third one on the website, as shown in the image below.
#
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/images/pandas_wbs_3.png">
#
# ### Exercise 2
# Modify the GDP column of the DataFrame, converting the value available in Million USD to Billion USD. Use the `round()` method of Numpy library to round the value to 2 decimal places. Modify the header of the DataFrame to `GDP (Billion USD)`.

# %%
# My Code
URL="https://web.archive.org/web/20230902185326/https://en.wikipedia.org/wiki/List_of_countries_by_GDP_%28nominal%29"

# Extract tables from webpage using Pandas. Retain table number 3 as the required dataframe.
df = pd.read_html(URL)[3]

# Replace the column headers with column numbers
df.columns = range(df.shape[1])

# Retain columns with index 0 and 2 (name of country and value of GDP quoted by IMF)
# Retain the Rows with index 1 to 10, indicating the top 10 economies of the world.
df = df[[0,2]].head(10)

# Assign column names as "Country" and "GDP (Million USD)"
df.columns = ["Country","GDP (Million USD)"]

# Change the data type of the 'GDP (Million USD)' column to integer. Use astype() method.
# Convert the GDP value in Million USD to Billion USD
# Use numpy.round() method to round the value to 2 decimal places.
df['GDP (Million USD)'] = np.round(df['GDP (Million USD)'].astype(int)/1000,2)

# Rename the column header from 'GDP (Million USD)' to 'GDP (Billion USD)'
df.rename(columns={'GDP (Million USD)': 'GDP (Billion USD)'}, inplace=True)

# Load the DataFrame to the CSV file named "Largest_economies.csv"
df.to_csv('Largest_economies.csv', index=False)


### solution:  
# Extract tables from webpage using Pandas. Retain table number 3 as the required dataframe.
tables = pd.read_html(URL)
df = tables[3]

# Replace the column headers with column numbers
df.columns = range(df.shape[1])

# Retain columns with index 0 and 2 (name of country and value of GDP quoted by IMF)
df = df[[0,2]]

# Retain the Rows with index 1 to 10, indicating the top 10 economies of the world.
df = df.iloc[1:11,:]

# Assign column names as "Country" and "GDP (Million USD)"
df.columns = ['Country','GDP (Million USD)']

# Change the data type of the 'GDP (Million USD)' column to integer. Use astype() method.
df['GDP (Million USD)'] = df['GDP (Million USD)'].astype(int)

# Convert the GDP value in Million USD to Billion USD
df[['GDP (Million USD)']] = df[['GDP (Million USD)']]/1000

# Use numpy.round() method to round the value to 2 decimal places.
df[['GDP (Million USD)']] = np.round(df[['GDP (Million USD)']], 2)

# Rename the column header from 'GDP (Million USD)' to 'GDP (Billion USD)'
df.rename(columns = {'GDP (Million USD)' : 'GDP (Billion USD)'})

# Load the DataFrame to the CSV file named "Largest_economies.csv"
df.to_csv('./Largest_economies.csv')
